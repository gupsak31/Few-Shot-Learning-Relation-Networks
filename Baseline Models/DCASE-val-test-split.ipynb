# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/DCASE-task1"
# Out:
# /content/drive/MyDrive/DCASE-task1

# %%
import numpy as np
import pandas as pd
import random

# %%
df = pd.read_csv("dcase1_other.csv")

# %%
df.shape[0]
# Out:
# 6758

# %%
indexes = [i for i in range(df.shape[0])]
random.shuffle(indexes)
df_val = df.iloc[indexes[:2000]]
df_test = df.iloc[indexes[2000:]]

# %%
df_val["class"].value_counts()
# Out:
# public_square    683
# airport          659
# tram             658
# Name: class, dtype: int64

# %%
df_test["class"].value_counts()
# Out:
# tram             1595
# airport          1593
# public_square    1570
# Name: class, dtype: int64

# %%
df_val.to_csv("dcase_val.csv", index = False)
df_test.to_csv("dcase_test.csv", index = False)
