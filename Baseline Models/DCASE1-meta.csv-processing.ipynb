# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/MyDrive/DCASE-task1
# Out:
# /content/gdrive/MyDrive/DCASE-task1

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("meta.csv")
df = df.rename(columns = {df.columns[0]: "all_data"})

# %%
df["file_name"] = df.apply(lambda row: row.all_data.split()[0], axis = 1)
df["class"] = df.apply(lambda row: row.all_data.split()[1], axis = 1)

df.drop(columns=["all_data"], inplace = True)

# %%
df
# Out:
#                                    file_name    class
# 0      audio/airport-lisbon-1000-40000-a.wav  airport
# 1      audio/airport-prague-1015-40019-a.wav  airport
# 2      audio/airport-prague-1023-40027-a.wav  airport
# 3      audio/airport-prague-1023-40038-a.wav  airport
# 4      audio/airport-prague-1034-40041-a.wav  airport
# ...                                      ...      ...
# 23030   audio/tram-barcelona-181-5627-s6.wav     tram
# 23031    audio/tram-helsinki-184-5724-s6.wav     tram
# 23032    audio/tram-lisbon-1100-43586-s6.wav     tram
# 23033      audio/tram-london-188-5815-s6.wav     tram
# 23034      audio/tram-lyon-1103-43145-s6.wav     tram
#
# [23035 rows x 2 columns]

# %%
df.to_csv("dcase1.csv", index = False)
