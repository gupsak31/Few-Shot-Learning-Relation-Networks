# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/UrbanSound8K"
# Out:
# /content/drive/MyDrive/UrbanSound8K

# %%
import numpy as np
import pandas as pd
import random

# %%
df = pd.read_csv("UrbanSound8K_other.csv")

# %%
indexes = [i for i in range(df.shape[0])]
random.shuffle(indexes)
df_val = df.iloc[indexes[:836]]
df_test = df.iloc[indexes[836:]]

# %%
df_val["class"].value_counts()
# Out:
# siren       452
# car_horn    194
# gun_shot    190
# Name: class, dtype: int64

# %%
df_test["class"].value_counts()
# Out:
# siren       457
# car_horn    215
# gun_shot    164
# Name: class, dtype: int64

# %%
df_val.to_csv("UrbanSound8K_val.csv", index = False)
df_test.to_csv("UrbanSound8K_test.csv", index = False)
